# %%
from bs4 import BeautifulSoup
import chardet
import datetime
import duckdb
import io
import pandas as pd
import requests

# %%
DATA_PATH = '../data/'
PATH_TO_CSV = DATA_PATH+'csv/'                # input
PATH_TO_ONS = PATH_TO_CSV+'ons/'              # input
FILENAME_ONS_LIST = \
[
    "12063_E10000008_AllCountiesInCountry_England_latest.csv",
    "23125_E10000011_AllCountiesInCountry_England_latest.csv",
    "23125_E10000011_AllLaInUK_latest.csv",
    "3676_E10000008_AllCountiesInCountry_England_latest.csv",
    "6233_E10000008_AllCountiesInCountry_England_latest.csv",
    "6233_E10000008_AllLaInUK_latest.csv",
    "6234_E10000008_AllCountiesInCountry_England_latest.csv",
    "6234_E10000008_AllLaInUK_latest.csv",
    "6238_E10000008_AllCountiesInCountry_England_latest.csv",
    "6238_E10000008_AllLaInUK_latest.csv",
    "6605_E10000008_AllCountiesInCountry_England_latest.csv",
    "6605_E10000008_AllLaInUK_latest.csv",
]
FILENAME_OTHERS_LIST = \
[
    "bar-617-chart-5.csv",
    "local_authority_data_for_corporate_and_finance.csv",
    "searches.csv",
    "series-040525.csv",
    "series-050525 copy.csv",
    "series-050525-2.csv",
    "series-050525-3.csv",
    "series-050525-4.csv",
    "series-050525.csv",
    "sparql_result.csv",
    "Table-617-chart-8.csv",
]

# %%
filename.split('.')[0]
# Out:
# '6605_E10000008_AllLaInUK_latest'

# %%
def read_header_ons_county_data(filepath: str, desc_df: pd.DataFrame, nrows: int=6):
    f"""
    reads the header of a data file, assumed to be in the ons county by county dataset format
    """

    filepath = PATH_TO_ONS + filename

    # header part of the csv:
    temp = pd.read_csv(filepath, nrows=nrows, header=None)
    metric                = temp[3].iloc[0]
    dataset_id            = temp[3].iloc[1]
    applicable_date_range = temp[3].iloc[2]
    collection_date       = temp[3].iloc[3]
    dataset_unit          = temp[3].iloc[4]
    data_kind             = temp[3].iloc[5]
    
    desc_df.loc[len(desc_df)] = [
        dataset_id,
        metric,
        applicable_date_range,
        collection_date,
        dataset_unit,
        data_kind,
        filename,
        filepath
    ]
    return desc_df

# %%
ons_description_df = pd.DataFrame(
    columns=[
        'id',
        'metric',
        'date_range',
        'date_collected',
        'unit',
        'kind', 
        'filename',
        'filepath'
    ]
)
ons_description_df
# Out:
# Empty DataFrame
# Columns: [id, metric, date_range, date_collected, unit, kind, filename, filepath]
# Index: []

# %% [markdown]
# # ons data overview

# %%
for filename in FILENAME_ONS_LIST:
    read_header_ons_county_data(filename, ons_description_df, nrows=6)

# %%
ons_description_df
# Out:
#        id                                             metric  \
# 0   12063  Percentage of physically active adults (aged 19+)
# 1   23125  Total expenditure on arts, tourism, & the hist...
# 2   23125  Total expenditure on arts, tourism, & the hist...
# 3    3676  % of children at expected level in Expressive ...
# 4    6233           Employees - Arts development and support
# 5    6233           Employees - Arts development and support
# 6    6234    Running expenses - Arts development and support
# 7    6234    Running expenses - Arts development and support
# 8    6238        Total Income - Arts development and support
# 9    6238        Total Income - Arts development and support
# 10   6605  Total expenditure on arts, tourism and histori...
# 11   6605  Total expenditure on arts, tourism and histori...
#
#             date_range date_collected            unit kind  \
# 0              2022/23    fin_2022_23               %  raw
# 1              2023/24    fin_2023_24  GBP per person  raw
# 2              2023/24    fin_2023_24  GBP per person  raw
# 3   2023/24 (academic)    sch_2023_24               %  raw
# 4              2023/24    fin_2023_24       GBP (000)  raw
# 5              2023/24    fin_2023_24       GBP (000)  raw
# 6              2023/24    fin_2023_24       GBP (000)  raw
# 7              2023/24    fin_2023_24       GBP (000)  raw
# 8              2023/24    fin_2023_24       GBP (000)  raw
# 9              2023/24    fin_2023_24       GBP (000)  raw
# 10             2023/24    fin_2023_24       GBP (000)  raw
# 11             2023/24    fin_2023_24       GBP (000)  raw
#
#                                              filename  \
# 0   12063_E10000008_AllCountiesInCountry_England_l...
# 1   23125_E10000011_AllCountiesInCountry_England_l...
# 2                23125_E10000011_AllLaInUK_latest.csv
# 3   3676_E10000008_AllCountiesInCountry_England_la...
# 4   6233_E10000008_AllCountiesInCountry_England_la...
# 5                 6233_E10000008_AllLaInUK_latest.csv
# 6   6234_E10000008_AllCountiesInCountry_England_la...
# 7                 6234_E10000008_AllLaInUK_latest.csv
# 8   6238_E10000008_AllCountiesInCountry_England_la...
# 9                 6238_E10000008_AllLaInUK_latest.csv
# 10  6605_E10000008_AllCountiesInCountry_England_la...
# 11                6605_E10000008_AllLaInUK_latest.csv
#
#                                              filepath
# 0   ../data/csv/ons/12063_E10000008_AllCountiesInC...
# 1   ../data/csv/ons/23125_E10000011_AllCountiesInC...
# 2   ../data/csv/ons/23125_E10000011_AllLaInUK_late...
# 3   ../data/csv/ons/3676_E10000008_AllCountiesInCo...
# 4   ../data/csv/ons/6233_E10000008_AllCountiesInCo...
# 5   ../data/csv/ons/6233_E10000008_AllLaInUK_lates...
# 6   ../data/csv/ons/6234_E10000008_AllCountiesInCo...
# 7   ../data/csv/ons/6234_E10000008_AllLaInUK_lates...
# 8   ../data/csv/ons/6238_E10000008_AllCountiesInCo...
# 9   ../data/csv/ons/6238_E10000008_AllLaInUK_lates...
# 10  ../data/csv/ons/6605_E10000008_AllCountiesInCo...
# 11  ../data/csv/ons/6605_E10000008_AllLaInUK_lates...

# %%
for idx, row in ons_description_df.iterrows():
    tablename  ='table_' + row['filename'].split('.')[0]
    filepath   =row['filepath']
    metric     =row['metric']
    unit       =row['unit']
    date_range =row['date_range']
    
    df = (
        pd.read_csv(filepath, skiprows=5, header=0)
        .rename(columns={'raw':metric})
        .assign(unit=unit, date_range=date_range)
    )
    display(df.head(3))
    
    with duckdb.connect(database = "../data/creatives.duckdb", read_only = False) as con:
        con.sql(f"DROP TABLE IF EXISTS {tablename}; CREATE TABLE {tablename} AS SELECT * FROM df;")
        con.sql(f"SELECT COUNT(*) FROM {tablename};")
# Out:
#        area label          area long label       area  \
# 0           Devon           Devon (County)  E10000008
# 1  Cambridgeshire  Cambridgeshire (County)  E10000003
# 2      Derbyshire      Derbyshire (County)  E10000007
#
#    Percentage of physically active adults (aged 19+) unit date_range
# 0                                               74.3    %    2022/23
# 1                                               71.3    %    2022/23
# 2                                               67.9    %    2022/23
#        area label          area long label       area  \
# 0     East Sussex     East Sussex (County)  E10000011
# 1  Cambridgeshire  Cambridgeshire (County)  E10000003
# 2      Derbyshire      Derbyshire (County)  E10000007
#
#    Total expenditure on arts, tourism, & the historic environment per head  \
# 0                                                  0
# 1                                                  1
# 2                                                  2
#
#              unit date_range
# 0  GBP per person    2023/24
# 1  GBP per person    2023/24
# 2  GBP per person    2023/24
#      area label          area long label       area  \
# 0   East Sussex     East Sussex (County)  E10000011
# 1          Adur          Adur (District)  E07000223
# 2  Amber Valley  Amber Valley (District)  E07000032
#
#   Total expenditure on arts, tourism, & the historic environment per head  \
# 0                                                  0
# 1                                                 14
# 2                                                  1
#
#              unit date_range
# 0  GBP per person    2023/24
# 1  GBP per person    2023/24
# 2  GBP per person    2023/24
#        area label          area long label       area  \
# 0           Devon           Devon (County)  E10000008
# 1  Cambridgeshire  Cambridgeshire (County)  E10000003
# 2      Derbyshire      Derbyshire (County)  E10000007
#
#    % of children at expected level in Expressive arts and design unit  \
# 0                                               88.8                %
# 1                                               86.3                %
# 2                                               85.3                %
#
#            date_range
# 0  2023/24 (academic)
# 1  2023/24 (academic)
# 2  2023/24 (academic)
#        area label          area long label       area  \
# 0           Devon           Devon (County)  E10000008
# 1  Cambridgeshire  Cambridgeshire (County)  E10000003
# 2      Derbyshire      Derbyshire (County)  E10000007
#
#    Employees - Arts development and support       unit date_range
# 0                                         0  GBP (000)    2023/24
# 1                                         0  GBP (000)    2023/24
# 2                                        58  GBP (000)    2023/24
#      area label          area long label       area  \
# 0         Devon           Devon (County)  E10000008
# 1          Adur          Adur (District)  E07000223
# 2  Amber Valley  Amber Valley (District)  E07000032
#
#   Employees - Arts development and support       unit date_range
# 0                                        0  GBP (000)    2023/24
# 1                                        0  GBP (000)    2023/24
# 2                                        0  GBP (000)    2023/24
#        area label          area long label       area  \
# 0           Devon           Devon (County)  E10000008
# 1  Cambridgeshire  Cambridgeshire (County)  E10000003
# 2      Derbyshire      Derbyshire (County)  E10000007
#
#   Running expenses - Arts development and support       unit date_range
# 0                                               0  GBP (000)    2023/24
# 1                                               0  GBP (000)    2023/24
# 2                                              69  GBP (000)    2023/24
#      area label          area long label       area  \
# 0         Devon           Devon (County)  E10000008
# 1          Adur          Adur (District)  E07000223
# 2  Amber Valley  Amber Valley (District)  E07000032
#
#   Running expenses - Arts development and support       unit date_range
# 0                                               0  GBP (000)    2023/24
# 1                                               0  GBP (000)    2023/24
# 2                                               0  GBP (000)    2023/24
#        area label          area long label       area  \
# 0           Devon           Devon (County)  E10000008
# 1  Cambridgeshire  Cambridgeshire (County)  E10000003
# 2      Derbyshire      Derbyshire (County)  E10000007
#
#   Total Income - Arts development and support       unit date_range
# 0                                           0  GBP (000)    2023/24
# 1                                           0  GBP (000)    2023/24
# 2                                          43  GBP (000)    2023/24
#      area label          area long label       area  \
# 0         Devon           Devon (County)  E10000008
# 1          Adur          Adur (District)  E07000223
# 2  Amber Valley  Amber Valley (District)  E07000032
#
#   Total Income - Arts development and support       unit date_range
# 0                                           0  GBP (000)    2023/24
# 1                                           0  GBP (000)    2023/24
# 2                                           0  GBP (000)    2023/24
#        area label          area long label       area  \
# 0           Devon           Devon (County)  E10000008
# 1  Cambridgeshire  Cambridgeshire (County)  E10000003
# 2      Derbyshire      Derbyshire (County)  E10000007
#
#   Total expenditure on arts, tourism and historic environment       unit  \
# 0                                                112           GBP (000)
# 1                                                737           GBP (000)
# 2                                              1,735           GBP (000)
#
#   date_range
# 0    2023/24
# 1    2023/24
# 2    2023/24
#      area label          area long label       area  \
# 0         Devon           Devon (County)  E10000008
# 1          Adur          Adur (District)  E07000223
# 2  Amber Valley  Amber Valley (District)  E07000032
#
#   Total expenditure on arts, tourism and historic environment       unit  \
# 0                                                112           GBP (000)
# 1                                                911           GBP (000)
# 2                                                186           GBP (000)
#
#   date_range
# 0    2023/24
# 1    2023/24
# 2    2023/24

# %%
# Out:
# 12063_E10000008_AllCountiesInCountry_England_latest

# %%
import datetime
datetime.datetime.now().strftime('%Y-%m-%d %H:%M')
# Out:
# '2025-05-09 02:03'
